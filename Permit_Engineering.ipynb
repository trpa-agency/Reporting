# %%
import pandas as pd
import os

folder_path = 'F:\Research and Analysis\Local Jurisdiction MOU data collection\Placer MOU Files\Placer'
dfs = []

# Loop through the files in the folder and identify CSV files
for file_name in os.listdir(folder_path):
    # Construct the full file path
    file_path = os.path.join(folder_path, file_name)
    
    # Read the CSV file into a DataFrame and append to the list
    df = pd.read_excel(file_path)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(dfs, ignore_index=True)

# Display the resulting DataFrame
print(final_df)
# Out:
#           Permit #         Parcel #                            Record Type  \
# 0      TRP16-90108  098-114-004-000                       TRPA MOU Project
# 1      TRP16-90217  112-230-001-000                       TRPA MOU Project
# 2      TRP17-90025  116-210-025-000          Tahoe Residential-TRPA review
# 3      TRP18-90010  094-251-013-000      TRPA/Building/Qualified Exempt/NA
# 4      TRP14-90040  116-030-024-000                       TRPA MOU Project
# ...            ...              ...                                    ...
# 13194  TRP24-90020  112-230-029-000      Residential Building TRPA Project
# 13195  TRP24-90021  094-252-007-000      Residential Building TRPA Project
# 13196  TRP24-90024  094-370-032-000       Non-Residential Qualified Exempt
# 13197  TRP24-90025  083-430-052-000  Residential Building Qualified Exempt
# 13198  TRP24-90026  083-470-026-000      Residential Building TRPA Project
#
#        Project Type                        Project Name  \
# 0               NaN               Li/ Letourmy Addition
# 1               NaN        Roth Roof/ ATF Deck Addition
# 2               NaN                       MIHIC NEW SFD
# 3               NaN                               BOYLE
# 4               NaN                  VOELKER - ADDITION
# ...             ...                                 ...
# 13194           NaN               Whittemore - Addition
# 13195           NaN                            Zeissler
# 13196           NaN  Tahoe Tavern #129 Interior Remodel
# 13197           NaN                   Kamcili - Remodel
# 13198           NaN              Viale-Remodel Addition
#
#                       Status     Opened  Number  Dir Street Name  ...  \
# 0      Construction Complete 2016-06-24   515.0  NaN      GROUSE  ...
# 1      Construction Complete 2016-11-30  1341.0  NaN       KINGS  ...
# 2      Construction Complete 2017-04-06  5641.0  NaN    RHODESIA  ...
# 3      Construction Complete 2018-01-23   732.0  NaN      CHAPEL  ...
# 4      Construction Complete 2014-08-25  5910.0  NaN      ANGOLA  ...
# ...                      ...        ...     ...  ...         ...  ...
# 13194               Received 2024-02-20  1342.0  NaN       KINGS  ...
# 13195               Received 2024-02-21   699.0  NaN      CHAPEL  ...
# 13196               Received 2024-02-26   300.0    W        LAKE  ...
# 13197               Received 2024-02-28  4087.0  NaN      GSTAAD  ...
# 13198               Received 2024-02-29  1008.0  NaN     SKYLINE  ...
#
#       Payment for Application Fee Payment for Security Payment for WQMF  \
# 0                          171.82               2500.0              NaN
# 1                           21.75               2500.0              NaN
# 2                         1171.41               3500.0          3673.50
# 3                             NaN                  NaN              NaN
# 4                          914.75               2500.0           491.04
# ...                           ...                  ...              ...
# 13194                         NaN                  NaN              NaN
# 13195                         NaN                  NaN              NaN
# 13196                         NaN                  NaN              NaN
# 13197                         NaN                  NaN              NaN
# 13198                         NaN                  NaN              NaN
#
#       Payment for AQMF Payment for OSMF Payment for ECMF  SERV_PROV_CODE  \
# 0                  NaN              NaN              NaN        PLACERCO
# 1                  NaN              NaN              NaN        PLACERCO
# 2               3258.4           1062.5              NaN        PLACERCO
# 3                  NaN              NaN              NaN        PLACERCO
# 4                  NaN              NaN              NaN        PLACERCO
# ...                ...              ...              ...             ...
# 13194              NaN              NaN              NaN        PLACERCO
# 13195              NaN              NaN              NaN        PLACERCO
# 13196              NaN              NaN              NaN        PLACERCO
# 13197              NaN              NaN              NaN        PLACERCO
# 13198              NaN              NaN              NaN        PLACERCO
#
#        B1_PER_ID1  B1_PER_ID2  B1_PER_ID3
# 0           16CAP           0       0036O
# 1           16CAP           0       00682
# 2           17CAP           0       001AS
# 3           18CAP           0       000BH
# 4           14CAP           0       002KW
# ...           ...         ...         ...
# 13194       24CAP           0       0016R
# 13195       24CAP           0       0018R
# 13196       24CAP           0       001DL
# 13197       24CAP           0       001EV
# 13198       24CAP           0       001FT
#
# [13199 rows x 56 columns]
